# %% [markdown]
# # EDIYA COFFEE 와 STARBUCKS

# %% [markdown]
# ![starbucks_ediya](staredi.jpg)

# %% [markdown]
# ## 스타벅스 옆에는 이디야 커피가 있다는 속설이 존재한다 과연 사실일까?
# * 국내 커피 프랜차이즈점 매출 1위 스타벅스와 매장수 1위 이디야의 전략은?
# * [기사 원문] (http://www.seoul.co.kr/news/newsView.php?id=20160919004005)

# %% [markdown]
# ### 데이터 정리
# * 모듈 import

# %%
import pandas as pd
import numpy as np
import folium 
from folium import plugins
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# 폰트 문제 해결하기
import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# ## EDIYA

# %% [markdown]
# * 데이터 가져오기

# %%
ediya1 = pd.read_excel("reediya.xlsx", encoding='euc_kr', thousands=',')
ediya1
# Out:
#       Brand       Name State City  Address  Longtitude   Latitude
# 0     이디야커피      강릉교동점   강원도  강릉시    25512  128.877935  37.765551
# 1     이디야커피  강릉올림픽선수촌점   강원도  강릉시    25522  128.868708  37.757826
# 2     이디야커피        옥천점   강원도  강릉시    25551  128.899181  37.759796
# 3     이디야커피       213점   강원도  강릉시    25539  128.894945  37.752061
# 4     이디야커피       215점   강원도  강릉시    25541  128.898632  37.755700
# 5     이디야커피       경동대점   강원도  고성군    24764  128.561728  38.252968
# 6     이디야커피      동해천곡점   강원도  동해시    25770  129.116011  37.520991
# 7     이디야커피      삼척교동점   강원도  삼척시    25924  129.175472  37.448195
# 8     이디야커피      속초교동점   강원도  속초시    24836  128.581392  38.199905
# 9     이디야커피      속초중앙점   강원도  속초시    24831  128.588617  38.205293
# 10    이디야커피    속초해수욕장점   강원도  속초시    24887  128.604997  38.186748
# 11    이디야커피      강원양구점   강원도  양구군    24525  127.989130  38.107091
# 12    이디야커피      강원양양점   강원도  양양군    25023  128.621333  38.075113
# 13    이디야커피       248점   강원도  양양군    25023  128.621333  38.075113
# 14    이디야커피        단관점   강원도  원주시    26490  127.956466  37.322156
# 15    이디야커피        무실점   강원도  원주시    26388  127.926370  37.337388
# 16    이디야커피      문막동화점   강원도  원주시    26367  127.829101  37.326699
# 17    이디야커피      원주태장점   강원도  원주시    26316  127.952895  37.384845
# 18    이디야커피     원주터미널점   강원도  원주시    26382  127.930088  37.343941
# 19    이디야커피    원주혁신도시점   강원도  원주시    26465  127.979314  37.325019
# 20    이디야커피        중앙점   강원도  원주시    26427  127.947781  37.350006
# 21    이디야커피        흥업점   강원도  원주시    26403  127.919939  37.303745
# 22    이디야커피       183점   강원도  원주시    26403  127.923010  37.301413
# 23    이디야커피       190점   강원도  원주시    26339  127.929895  37.369118
# 24    이디야커피       235점   강원도  원주시    26464  127.987822  37.325326
# 25    이디야커피        원통점   강원도  인제군    24618  128.208210  38.121386
# 26    이디야커피        인제점   강원도  인제군    24635  128.172674  38.069132
# 27    이디야커피       242점   강원도  인제군    24646  128.095524  37.988093
# 28    이디야커피       하이원점   강원도  정선군    26154  128.827807  37.209488
# 29    이디야커피     동송터미널점   강원도  철원군    24018  127.218471  38.207185
# ...     ...        ...   ...  ...      ...         ...        ...
# 1682  이디야커피      증평중앙점  충청북도  증평군    27927  127.581331  36.785897
# 1683  이디야커피       254점  충청북도  증평군    27927  127.580098  36.785991
# 1684  이디야커피       214점  충청북도  진천군    27833  127.441859  36.854400
# 1685  이디야커피       상당로점  충청북도  청주시    28514  127.490355  36.638259
# 1686  이디야커피      청주금천점  충청북도  청주시    28727  127.503559  36.630050
# 1687  이디야커피     청주성안길점  충청북도  청주시    28530  127.489389  36.632253
# 1688  이디야커피  청주성안홈플러스점  충청북도  청주시    28524  127.485797  36.636013
# 1689  이디야커피        개신점  충청북도  청주시    28612  127.445074  36.619933
# 1690  이디야커피     청주산남동점  충청북도  청주시    28625  127.468878  36.611471
# 1691  이디야커피     청주성화동점  충청북도  청주시    28637  127.455425  36.618593
# 1692  이디야커피       충북대점  충청북도  청주시    28643  127.460250  36.633746
# 1693  이디야커피   오창2산업단지점  충청북도  청주시    28117  127.451082  36.732764
# 1694  이디야커피    오창과학단지점  충청북도  청주시    28120  127.427761  36.711486
# 1695  이디야커피     청주내덕동점  충청북도  청주시    28485  127.480430  36.655807
# 1696  이디야커피       청주대점  충청북도  청주시    28489  127.488332  36.651750
# 1697  이디야커피      청주여고점  충청북도  청주시    28326  127.491571  36.669320
# 1698  이디야커피    청주율량중앙점  충청북도  청주시    28321  127.499992  36.664723
# 1699  이디야커피     청주복대동점  충청북도  청주시    28423  127.436844  36.634043
# 1700  이디야커피   청주복대사거리점  충청북도  청주시    28597  127.441026  36.632423
# 1701  이디야커피     청주봉명동점  충청북도  청주시    28465  127.458783  36.650033
# 1702  이디야커피      청주분평점  충청북도  청주시    28451  127.462411  36.646211
# 1703  이디야커피    청주지웰시티점  충청북도  청주시    28427  127.428435  36.641583
# 1704  이디야커피     청주하복대점  충청북도  청주시    28420  127.429622  36.635325
# 1705  이디야커피       174점  충청북도  청주시    28396  127.431131  36.626212
# 1706  이디야커피       184점  충청북도  청주시    28462  127.455569  36.653705
# 1707  이디야커피       225점  충청북도  청주시    28423  127.436670  36.633367
# 1708  이디야커피        용산점  충청북도  충주시    27403  127.940872  36.961557
# 1709  이디야커피     충주성서동점  충청북도  충주시    27387  127.931339  36.972312
# 1710  이디야커피     충주연수동점  충청북도  충주시    27352  127.939719  36.985320
# 1711  이디야커피    충주연수중앙점  충청북도  충주시    27347  127.930382  36.987568
#
# [1712 rows x 7 columns]

# %% [markdown]
# ⇒ 전체매장수 1712개

# %% [markdown]
# * 구조를 보기 쉽게 피벗 테이블로 정리

# %%
pd.pivot_table(ediya1, index=["State","City", "Name"]).head()
# Out:
#                       Address   Latitude  Longtitude
# State City Name
# 강원도   강릉시  213점       25539.0  37.752061  128.894945
#            215점       25541.0  37.755700  128.898632
#            강릉교동점      25512.0  37.765551  128.877935
#            강릉올림픽선수촌점  25522.0  37.757826  128.868708
#            옥천점        25551.0  37.759796  128.899181

# %% [markdown]
# * 각 도시별 이디야 매장 개수
# * 그래프로 시각화

# %%
ediya1.City.value_counts().head(20)
# Out:
# 서울특별시    427
# 부산광역시    144
# 인천광역시    109
# 울산광역시     58
# 전주시       42
# 수원시       41
# 고양시       40
# 부천시       37
# 용인시       37
# 대구광역시     32
# 창원시       31
# 남양주시      31
# 성남시       28
# 광주광역시     25
# 청주시       23
# 김해시       21
# 대전광역시     21
# 의정부시      20
# 시흥시       19
# 안산시       19
# Name: City, dtype: int64

# %%
figure = plt.figure(figsize=(22,6))
axes = figure.add_subplot(111)
axes.set(title = "The Top 20 Cities in EDIYA")
ediya1.City.value_counts().head(20).plot(kind="bar", color = "blue")

# %% [markdown]
# ## STARBUCKS

# %% [markdown]
# * 데이터 가져오기

# %%
starbucks1 = pd.read_excel("stb11.xlsx")
starbucks1
# Out:
#      Brand           Name State City  Address  Longtitude   Latitude
# 0     스타벅스         강릉안목항점   강원도  강릉시    25556  128.948709  37.771400
# 1     스타벅스         강릉중앙로점   강원도  강릉시    25540  128.896189  37.754547
# 2     스타벅스      대명델피노리조트점   강원도  고성군    24768  128.493408  38.213128
# 3     스타벅스          동해DT점   강원도  동해시    25768  129.114687  37.520174
# 4     스타벅스         설악쏘라노점   강원도  속초시    24801  128.528676  38.210587
# 5     스타벅스        설악워터피아점   강원도  속초시    24801  128.527867  38.207735
# 6     스타벅스          속초DT점   강원도  속초시    24872  128.584418  38.189907
# 7     스타벅스         속초중앙로점   강원도  속초시    24835  128.589463  38.202621
# 8     스타벅스            문막점   강원도  원주시    26373  127.816601  37.306955
# 9     스타벅스          원주단구점   강원도  원주시    26484  127.949284  37.330461
# 10    스타벅스          원주무실점   강원도  원주시    26392  127.930245  37.333110
# 11    스타벅스         원주터미널점   강원도  원주시    26382  127.931104  37.343852
# 12    스타벅스            강대점   강원도  춘천시    24287  127.745087  37.872760
# 13    스타벅스           강원대점   강원도  춘천시    24287  127.745087  37.872760
# 14    스타벅스          춘천명동점   강원도  춘천시    24353  127.727566  37.880037
# 15    스타벅스        춘천석사DT점   강원도  춘천시    24378  127.739324  37.856664
# 16    스타벅스         춘천이마트점   강원도  춘천시    24435  127.717260  37.863956
# 17    스타벅스        춘천후평DT점   강원도  춘천시    24304  127.750622  37.879421
# 18    스타벅스         용평리조트점   강원도  평창군    25352  128.705542  37.650953
# 19    스타벅스         휘닉스파크점   강원도  평창군    25307  128.309596  37.573750
# 20    스타벅스        오션월드2호점   강원도  홍천군    25102  127.687273  37.652324
# 21    스타벅스          고양DT점   경기도  고양시    10270  126.905418  37.709641
# 22    스타벅스          고양삼송점   경기도  고양시    10568  126.889976  37.663734
# 23    스타벅스  스타필드고양3F잇토피아점   경기도  고양시    10595  126.894996  37.646968
# 24    스타벅스          원당DT점   경기도  고양시    10462  126.837584  37.658211
# 25    스타벅스            행신역   경기도  고양시    10526  126.834455  37.614030
# 26    스타벅스             화정   경기도  고양시    10500  126.833382  37.632680
# 27    스타벅스            화정역   경기도  고양시    10500  126.832722  37.633610
# 28    스타벅스            화정점   경기도  고양시    10500  126.831432  37.633534
# 29    스타벅스        라페스타광장점   경기도  고양시    10401  126.770149  37.659681
# ...    ...            ...   ...  ...      ...         ...        ...
# 1004  스타벅스          아산탕정점  충청남도  아산시    31456  127.058288  36.798550
# 1005  스타벅스         아산터미널점  충청남도  아산시    31526  127.016275  36.783891
# 1006  스타벅스          충남아산점  충청남도  아산시    31538  126.932769  36.773114
# 1007  스타벅스         충청예산군점  충청남도  예산군    32406  126.668639  36.705452
# 1008  스타벅스        천안ICDT점  충청남도  천안시    31124  127.161502  36.820275
# 1009  스타벅스       천안아이씨디티점  충청남도  천안시    31124  127.161355  36.820400
# 1010  스타벅스          천안안서점  충청남도  천안시    31066  127.179858  36.830126
# 1011  스타벅스          천안청당점  충청남도  천안시    31198  127.157377  36.785542
# 1012  스타벅스         천안터미널점  충청남도  천안시    31120  127.157847  36.819321
# 1013  스타벅스         천안동남구점  충청남도  천안시    31120  127.153039  36.819314
# 1014  스타벅스          천안두정점  충청남도  천안시    31100  127.134827  36.833998
# 1015  스타벅스          천안불당점  충청남도  천안시    31163  127.110956  36.810040
# 1016  스타벅스         천안성정DT  충청남도  천안시    31134  127.140293  36.825413
# 1017  스타벅스         천안쌍용역점  충청남도  천안시    31174  127.122233  36.793155
# 1018  스타벅스         천안이마트점  충청남도  천안시    31180  127.127098  36.795921
# 1019  스타벅스          충남청양점  충청남도  청양군    33333  126.803029  36.449946
# 1020  스타벅스          청주서문점  충청북도  청주시    28528  127.486002  36.635347
# 1021  스타벅스          청주성화점  충청북도  청주시    28612  127.446063  36.617631
# 1022  스타벅스           충북대점  충청북도  청주시    28642  127.459711  36.633987
# 1023  스타벅스        오창과학단지점  충청북도  청주시    28115  127.423269  36.716493
# 1024  스타벅스        오창호수공원점  충청북도  청주시    28120  127.427720  36.712477
# 1025  스타벅스        청주율량DT점  충청북도  청주시    28333  127.492934  36.666270
# 1026  스타벅스          청주강서점  충청북도  청주시    28377  127.429617  36.625385
# 1027  스타벅스        청주봉명DT점  충청북도  청주시    28451  127.464487  36.646725
# 1028  스타벅스        청주봉명DT점  충청북도  청주시    28451  127.464543  36.646770
# 1029  스타벅스        청주지웰시티점  충청북도  청주시    28424  127.425105  36.642738
# 1030  스타벅스         청주터미널점  충청북도  청주시    28396  127.432258  36.626560
# 1031  스타벅스          현대충청점  충청북도  청주시    28424  127.426554  36.644863
# 1032  스타벅스          충주성서점  충청북도  충주시    27387  127.932913  36.970510
# 1033  스타벅스          충주연수점  충청북도  충주시    27352  127.939912  36.982734
#
# [1034 rows x 7 columns]

# %% [markdown]
# ⇒전체 매장수 1034개

# %% [markdown]
# * 구조를 보기 쉽게 피벗 테이블로 정리

# %%
pd.pivot_table(starbucks1, index=["State", "City", "Name"]).head()
# Out:
#                       Address   Latitude  Longtitude
# State City Name
# 강원도   강릉시  강릉안목항점     25556.0  37.771400  128.948709
#            강릉중앙로점     25540.0  37.754547  128.896189
#       고성군  대명델피노리조트점  24768.0  38.213128  128.493408
#       동해시  동해DT점      25768.0  37.520174  129.114687
#       속초시  설악쏘라노점     24801.0  38.210587  128.528676

# %% [markdown]
# * 각 도시별 스타벅스 매장 수 확인
# * 그래프로 시각화

# %%
starbucks1.City.value_counts().head(20)
# Out:
# 서울특별시      390
# 부산광역시       89
# 대구광역시       56
# 광주광역시       40
# 대전광역시       40
# 인천광역시       36
# 성남시         35
# 고양시         27
# 울산광역시       21
# 수원시         18
# 용인시         17
# 제주특별자치도     14
# 창원시         13
# 청주시         12
# 부천시         11
# 천안시         11
# 포항시         11
# 안양시          9
# 전주시          8
# 경주시          7
# Name: City, dtype: int64

# %%
figure = plt.figure(figsize=(22,6))
axes = figure.add_subplot(111)
axes.set(title = "The Top 20 Cities in Starbucks")
starbucks1.City.value_counts().head(20).plot(kind="bar", color = "green")

# %% [markdown]
# ## 도시 별 인구 수

# %% [markdown]
# * 데이터 가져오기
# * 그래프로 시각화

# %%
pop = pd.read_excel("Population.xlsx", encoding='euc_kr', thousands=',')
pop.head()
# Out:
#     City  Population
# 0  서울특별시     9805506
# 1  부산광역시     3440484
# 2  대구광역시     2461002
# 3  인천광역시     2913024
# 4  광주광역시     1501557

# %%
figure = plt.figure(figsize=(22,6))
axes = figure.add_subplot(111)
axes.set(title = "The Top 20 Cities in Population")
ediya1.City.value_counts().head(20).plot(kind="bar", color = "yellow")

# %% [markdown]
# * 인구가 많은 도시 순서대로 정렬

# %%
pop.sort_values(by='Population', ascending=False).head(20)
# Out:
#         City  Population
# 0      서울특별시     9805506
# 1      부산광역시     3440484
# 3      인천광역시     2913024
# 2      대구광역시     2461002
# 5      대전광역시     1535445
# 4      광주광역시     1501557
# 8        수원시     1207032
# 6      울산광역시     1166033
# 150      창원시     1053551
# 17       고양시      999098
# 27       용인시      982590
# 9        성남시      951518
# 12       부천시      844043
# 60       청주시      840338
# 16       안산시      743072
# 84       전주시      657766
# 32       화성시      655350
# 21      남양주시      641589
# 69       천안시      638752
# 162  제주특별자치도      623332

# %% [markdown]
# * 스타벅스와 이디야가 어느 도시에 매장을 집중시켰는지 더욱 보기 쉬운 그래프

# %%
figure = plt.figure(figsize=(10,10))
axes = figure.add_subplot(111)
axes.set(title = "Starbucks")
starbucks1['City'].value_counts().plot(kind="pie", colors = ["green", "blue", "red", "yellow"])
plt.show()

# %%
figure = plt.figure(figsize=(10,10))
axes = figure.add_subplot(111)
axes.set(title = "EDIYA") 
ediya1['City'].value_counts().plot(kind="pie")
plt.show()

# %% [markdown]
# ## 이디야 ÷ 스타벅스
# * 각 도시 별로 스타벅스 매장 1개에 몇개의 이디야가 있는지 확인

# %% [markdown]
# ### 데이터 다듬기

# %% [markdown]
# * 앞에 있던 스타벅스 매장 수 데이터들을 테이블 형식으로 바꾸는 과정

# %%
sb4 = starbucks1.City.value_counts().to_frame()
sb4.head()
# Out:
#        City
# 서울특별시   390
# 부산광역시    89
# 대구광역시    56
# 광주광역시    40
# 대전광역시    40

# %%
sb4["Number_S"] = sb4["City"]
sb4.head()
# Out:
#        City  Number_S
# 서울특별시   390       390
# 부산광역시    89        89
# 대구광역시    56        56
# 광주광역시    40        40
# 대전광역시    40        40

# %%
sb4["City"] = sb4.index
sb4.head()
# Out:
#         City  Number_S
# 서울특별시  서울특별시       390
# 부산광역시  부산광역시        89
# 대구광역시  대구광역시        56
# 광주광역시  광주광역시        40
# 대전광역시  대전광역시        40

# %% [markdown]
# * 이디야 매장 수 데이터도 테이블 형식으로 다듬기

# %%
ed4 = ediya1.City.value_counts().to_frame()
ed4.head()
# Out:
#        City
# 서울특별시   427
# 부산광역시   144
# 인천광역시   109
# 울산광역시    58
# 전주시      42

# %%
ed4["Number_E"] = ed4["City"]
ed4["City"] = ed4.index
ed4.head()
# Out:
#         City  Number_E
# 서울특별시  서울특별시       427
# 부산광역시  부산광역시       144
# 인천광역시  인천광역시       109
# 울산광역시  울산광역시        58
# 전주시      전주시        42

# %% [markdown]
# ### 다듬은 데이터들을 합치기

# %% [markdown]
# * City를 중심으로 merge함수 이용
# * Number_S는 스타벅스 매장 수
# * Number_E는 이디야 매장 수

# %%
sbed4 = pd.merge(sb4,ed4, on="City")
sbed4
# Out:
#        City  Number_S  Number_E
# 0     서울특별시       390       427
# 1     부산광역시        89       144
# 2     대구광역시        56        32
# 3     광주광역시        40        25
# 4     대전광역시        40        21
# 5     인천광역시        36       109
# 6       성남시        35        28
# 7       고양시        27        40
# 8     울산광역시        21        58
# 9       수원시        18        41
# 10      용인시        17        37
# 11  제주특별자치도        14        12
# 12      창원시        13        31
# 13      청주시        12        23
# 14      부천시        11        37
# 15      천안시        11        11
# 16      포항시        11        12
# 17      안양시         9        19
# 18      전주시         8        42
# 19      경주시         7        17
# 20      경산시         7         5
# 21      구미시         7         7
# 22      안산시         7        19
# 23      광명시         7         8
# 24      김포시         6        15
# 25      화성시         6        12
# 26     의정부시         6        20
# 27      김해시         6        21
# 28      진주시         6        16
# 29  세종특별자치시         6         7
# ..      ...       ...       ...
# 43      순천시         3        10
# 44      군포시         3         7
# 45      파주시         2        16
# 46      오산시         2         2
# 47      충주시         2         4
# 48      강릉시         2         5
# 49      서산시         2         3
# 50      익산시         2         8
# 51      안동시         2         8
# 52     동두천시         2         2
# 53      구리시         2         8
# 54      군산시         2        10
# 55      사천시         1         2
# 56      동해시         1         1
# 57      광주시         1        10
# 58      홍천군         1         3
# 59      양주시         1        12
# 60      과천시         1         2
# 61      여주시         1         3
# 62      예산군         1         5
# 63      고성군         1         2
# 64      문경시         1         3
# 65      논산시         1         3
# 66      김천시         1         2
# 67      광양시         1         5
# 68      공주시         1         4
# 69      포천시         1         9
# 70      안성시         1         1
# 71      당진시         1         5
# 72      통영시         1         3
#
# [73 rows x 3 columns]

# %% [markdown]
# * 병합한 데이터들을 따로 엑셀로 저장하기

# %%
sbed4.to_csv("sb_ed.csv", mode='w')

# %% [markdown]
# ### 이디야매장수 / 스타벅스 매장수
# * E/S 열 생성

# %%
sbed4["E/S"] = (sbed4["Number_E"] / sbed4["Number_S"])
sbed4
# Out:
#        City  Number_S  Number_E        E/S
# 0     서울특별시       390       427   1.094872
# 1     부산광역시        89       144   1.617978
# 2     대구광역시        56        32   0.571429
# 3     광주광역시        40        25   0.625000
# 4     대전광역시        40        21   0.525000
# 5     인천광역시        36       109   3.027778
# 6       성남시        35        28   0.800000
# 7       고양시        27        40   1.481481
# 8     울산광역시        21        58   2.761905
# 9       수원시        18        41   2.277778
# 10      용인시        17        37   2.176471
# 11  제주특별자치도        14        12   0.857143
# 12      창원시        13        31   2.384615
# 13      청주시        12        23   1.916667
# 14      부천시        11        37   3.363636
# 15      천안시        11        11   1.000000
# 16      포항시        11        12   1.090909
# 17      안양시         9        19   2.111111
# 18      전주시         8        42   5.250000
# 19      경주시         7        17   2.428571
# 20      경산시         7         5   0.714286
# 21      구미시         7         7   1.000000
# 22      안산시         7        19   2.714286
# 23      광명시         7         8   1.142857
# 24      김포시         6        15   2.500000
# 25      화성시         6        12   2.000000
# 26     의정부시         6        20   3.333333
# 27      김해시         6        21   3.500000
# 28      진주시         6        16   2.666667
# 29  세종특별자치시         6         7   1.166667
# ..      ...       ...       ...        ...
# 43      순천시         3        10   3.333333
# 44      군포시         3         7   2.333333
# 45      파주시         2        16   8.000000
# 46      오산시         2         2   1.000000
# 47      충주시         2         4   2.000000
# 48      강릉시         2         5   2.500000
# 49      서산시         2         3   1.500000
# 50      익산시         2         8   4.000000
# 51      안동시         2         8   4.000000
# 52     동두천시         2         2   1.000000
# 53      구리시         2         8   4.000000
# 54      군산시         2        10   5.000000
# 55      사천시         1         2   2.000000
# 56      동해시         1         1   1.000000
# 57      광주시         1        10  10.000000
# 58      홍천군         1         3   3.000000
# 59      양주시         1        12  12.000000
# 60      과천시         1         2   2.000000
# 61      여주시         1         3   3.000000
# 62      예산군         1         5   5.000000
# 63      고성군         1         2   2.000000
# 64      문경시         1         3   3.000000
# 65      논산시         1         3   3.000000
# 66      김천시         1         2   2.000000
# 67      광양시         1         5   5.000000
# 68      공주시         1         4   4.000000
# 69      포천시         1         9   9.000000
# 70      안성시         1         1   1.000000
# 71      당진시         1         5   5.000000
# 72      통영시         1         3   3.000000
#
# [73 rows x 4 columns]

# %% [markdown]
# ### 기존 데이터에 인구수도 추가
# * 다시 merge를 이용해서 pop 데이터와 병합

# %%
sbed_o2 = pd.merge(sbed4, pop, on="City")
sbed_o2
# Out:
#        City  Number_S  Number_E        E/S  Population
# 0     서울특별시       390       427   1.094872     9805506
# 1     부산광역시        89       144   1.617978     3440484
# 2     대구광역시        56        32   0.571429     2461002
# 3     광주광역시        40        25   0.625000     1501557
# 4     대전광역시        40        21   0.525000     1535445
# 5     인천광역시        36       109   3.027778     2913024
# 6       성남시        35        28   0.800000      951518
# 7       고양시        27        40   1.481481      999098
# 8     울산광역시        21        58   2.761905     1166033
# 9       수원시        18        41   2.277778     1207032
# 10      용인시        17        37   2.176471      982590
# 11  제주특별자치도        14        12   0.857143      623332
# 12      창원시        13        31   2.384615     1053551
# 13      청주시        12        23   1.916667      840338
# 14      부천시        11        37   3.363636      844043
# 15      천안시        11        11   1.000000      638752
# 16      포항시        11        12   1.090909      510360
# 17      안양시         9        19   2.111111      582049
# 18      전주시         8        42   5.250000      657766
# 19      경주시         7        17   2.428571      262769
# 20      경산시         7         5   0.714286      279751
# 21      구미시         7         7   1.000000      422237
# 22      안산시         7        19   2.714286      743072
# 23      광명시         7         8   1.142857      334361
# 24      김포시         6        15   2.500000      365770
# 25      화성시         6        12   2.000000      655350
# 26     의정부시         6        20   3.333333      424722
# 27      김해시         6        21   3.500000      532912
# 28      진주시         6        16   2.666667      352807
# 29  세종특별자치시         6         7   1.166667      242507
# ..      ...       ...       ...        ...         ...
# 44      군포시         3         7   2.333333      284301
# 45      파주시         2        16   8.000000      423957
# 46      오산시         2         2   1.000000      215478
# 47      충주시         2         4   2.000000      211890
# 48      강릉시         2         5   2.500000      215977
# 49      서산시         2         3   1.500000      169643
# 50      익산시         2         8   4.000000      300929
# 51      안동시         2         8   4.000000      167664
# 52     동두천시         2         2   1.000000       98625
# 53      구리시         2         8   4.000000      183905
# 54      군산시         2        10   5.000000      276394
# 55      사천시         1         2   2.000000      112394
# 56      동해시         1         1   1.000000       89527
# 57      광주시         1        10  10.000000      322302
# 58      홍천군         1         3   3.000000       66791
# 59      양주시         1        12  12.000000      207009
# 60      과천시         1         2   2.000000       60923
# 61      여주시         1         3   3.000000      110273
# 62      예산군         1         5   5.000000       79425
# 63      고성군         1         2   2.000000       28984
# 64      고성군         1         2   2.000000       53123
# 65      문경시         1         3   3.000000       71038
# 66      논산시         1         3   3.000000      124202
# 67      김천시         1         2   2.000000      139709
# 68      광양시         1         5   5.000000      144364
# 69      공주시         1         4   4.000000      112928
# 70      포천시         1         9   9.000000      162698
# 71      안성시         1         1   1.000000      196362
# 72      당진시         1         5   5.000000      166043
# 73      통영시         1         3   3.000000      136035
#
# [74 rows x 5 columns]

# %% [markdown]
# * 데이터 원본이 변형하는것을 막기위해 이름을 바꿔가며 사용

# %%
sbed9 = sbed_o2

# %%
sbed10 = sbed_o2

# %%
sbed9.set_index("City", inplace=True)

# %% [markdown]
# ## 상관관계 확인

# %% [markdown]
# ### 인구수와 E/S비율간의 상관관계 확인

# %%
np.corrcoef(sbed9["E/S"], sbed9["Population"])
# Out:
# array([[ 1.        , -0.17546829],
#        [-0.17546829,  1.        ]])

# %% [markdown]
# ⇒ 음의 상관관계이지만 크게 관련은 없는것으로 나옴

# %% [markdown]
# ### 상관관계를 그래프로 그려서 쉽게 확인해보자

# %%
graph2 = np.polyfit(sbed9['Population'], sbed9['E/S'], 1)

g1 = np.poly1d(graph2) # y축
gx = np.linspace(100000, 700000, 100) # x축

# 오차를 추가한다.
sbed9['Mi'] = np.abs(5 - g1(sbed9['Population']))

gp_sort = sbed9.sort_values(by='Mi', ascending=False)
gp_sort.head()
# Out:
#     City  Number_S  Number_E       E/S  Population        Mi
# 0  서울특별시       390       427  1.094872     9805506  4.929116
# 1  부산광역시        89       144  1.617978     3440484  3.010847
# 5  인천광역시        36       109  3.027778     2913024  2.851883
# 2  대구광역시        56        32  0.571429     2461002  2.715654
# 4  대전광역시        40        21  0.525000     1535445  2.436712

# %%
plt.figure(figsize=(20,14))
plt.scatter(sbed9['Population'], sbed9['E/S'], 
            c=sbed9['Mi'], s=50)
plt.plot(gx, g1(gx), ls='dashed', lw=3, color='r')

for n in range(10):
    plt.text(sbed9['Population'][n]*1.02, sbed9['E/S'][n]*0.98, 
             sbed9.index[n], fontsize=15)
    
plt.xlabel('Population')
plt.ylabel('E/S')
plt.colorbar()
plt.grid()
plt.show()

# %% [markdown]
# ⇒ 확인이 어렵다

# %% [markdown]
# ### 인구수가 적은 도시만 확인
# * 전체를 한번에 확인하기에는 무리가 있어보인다
# * 그렇다면 인구수가 적은 도시 20개만 이용하여 따로 확인해보자

# %%
sbed_tt = sbed10.sort_values(by='Population', ascending=False)

# %%
sbed_ttt = sbed_tt.tail(20)

# %%
graph_t = np.polyfit(sbed_ttt['Population'], sbed_ttt['E/S'], 1)

gt1 = np.poly1d(graph_t) # y축
gtx = np.linspace(100000, 700000, 100) # x축

# 오차를 추가한다.
sbed_ttt['Mi'] = np.abs(5 - gt1(sbed_ttt['Population']))

gpt_sort = sbed_ttt.sort_values(by='Mi', ascending=False)
gpt_sort.head()
# Out:
# C:\Users\jyy48\Miniconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    City  Number_S  Number_E  E/S  Population        Mi
# 63  고성군         1         2  2.0       28984  3.582447
# 64  고성군         1         2  2.0       53123  3.084180
# 60  과천시         1         2  2.0       60923  2.923175
# 58  홍천군         1         3  3.0       66791  2.802050
# 65  문경시         1         3  3.0       71038  2.714385

# %%
plt.figure(figsize=(15,15))
plt.scatter(sbed_ttt['Population'], sbed_ttt['E/S'], 
            c=sbed_ttt['Mi'], s=50)
plt.plot(gtx, gt1(gtx), ls='dashed', lw=3, color='r')

for n in range(10):
    plt.text(sbed_ttt['Population'][n]*1.02, sbed_ttt['E/S'][n]*0.98, 
             sbed_ttt.index[n], fontsize=15)
    
plt.xlabel('Population')
plt.ylabel('E/S')
plt.colorbar()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-155-e378f8e8c175> in <module>()
#       5
#       6 for n in range(10):
# ----> 7     plt.text(sbed_ttt['Population'][n]*1.02, sbed_ttt['E/S'][n]*0.98,
#       8              sbed_ttt.index[n], fontsize=15)
#       9
#
# ~\Miniconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# ~\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2558         try:
#    2559             return self._engine.get_value(s, k,
# -> 2560                                           tz=getattr(series.dtype, 'tz', None))
#    2561         except KeyError as e1:
#    2562             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %% [markdown]
# ⇒ 위 좌표들을 대표하는 직선이 양의 상관관계를 또렷하게 나타낸다

# %% [markdown]
# * 진짜 그런지 확인해보자

# %%
np.corrcoef(sbed_ttt["E/S"], sbed_ttt["Population"])
# Out:
# array([[1.        , 0.45250225],
#        [0.45250225, 1.        ]])

# %% [markdown]
# ⇒ 비교적 뚜렷한 양의 상관관계를 가진다고 나온다

# %% [markdown]
# ### 인구수가 많은 도시도 확인
# * 그렇다면 인구수 상위 20개 도시도 확인해보자

# %%
sbed_h = sbed_tt.head(20)

# %%
graph_h = np.polyfit(sbed_h['Population'], sbed_h['E/S'], 1)

gh1 = np.poly1d(graph_h) # y축
ghx = np.linspace(100000, 700000, 100) # x축

# 오차를 추가한다.
sbed_h['Mi'] = np.abs(5 - gh1(sbed_h['Population']))

ght_sort = sbed_h.sort_values(by='Mi', ascending=False)
ght_sort.head()
# Out:
# C:\Users\jyy48\Miniconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#        Number_S  Number_E       E/S  Population        Mi
# City
# 서울특별시     390.0     427.0  1.094872     9805506  4.236035
# 부산광역시      89.0     144.0  1.617978     3440484  3.204249
# 인천광역시      36.0     109.0  3.027778     2913024  3.118746
# 대구광역시      56.0      32.0  0.571429     2461002  3.045472
# 대전광역시      40.0      21.0  0.525000     1535445  2.895437

# %%
plt.figure(figsize=(15,15))
plt.scatter(sbed_h['Population'], sbed_h['E/S'], 
            c=sbed_h['Mi'], s=50)
plt.plot(ghx, gh1(ghx), ls='dashed', lw=3, color='r')

for n in range(10):
    plt.text(sbed_h['Population'][n]*1.02, sbed_h['E/S'][n]*0.98, 
             sbed_h.index[n], fontsize=10)
    
plt.xlabel('Population')
plt.ylabel('E/S')
plt.colorbar()
plt.grid()
plt.show()

# %% [markdown]
# ⇒ 시각적으로는 확인이 힘들어보이니 상관분석을 해보자

# %%
np.corrcoef(sbed_h["E/S"], sbed_h["Population"])
# Out:
# array([[ 1.        , -0.24425858],
#        [-0.24425858,  1.        ]])

# %% [markdown]
# ⇒ 낮긴하지만 음의 상관관계를 나타낸다고 나온다

# %% [markdown]
# ## 상관분석, 그래프를 이용하여 E/S와 인구수의 상관관계를 알아보았다

# %% [markdown]
# ### 분석을 해보니 인구수가 많은 도시는 이디야보다 스타벅스가 약간 많다는 것(음의 상관관계)

# %% [markdown]
# * WHY?

# %% [markdown]
# 전체 매장수는 이디야가 700개 이상 많지만 원형그래프에서 볼 수 있듯 스타벅스는 몇개 도시에 매장수가 몰려있음
# 그 결과 상위 20개 도시 매장수 합에서는 스타벅스가 조금 더 많은 것으로 나옴

# %% [markdown]
# 몇몇 도시에서는 이디야가 스타벅스의 절반 수준밖에 안되는 매장 수를 가지고 있고

# %% [markdown]
# 어느 도시에는 스타벅스보다 3배의 매장을 가지고 있음

# %% [markdown]
# ### 인구수가 적은 도시는 스타벅스보다 이디야가 많다는것을 확인하였다(양의 상관관계)

# %% [markdown]
# * WHY?

# %% [markdown]
# 스타벅스는 대도시로 매장 수가 쏠려있는 반면 이디야는 인구수가 적은 중소도시에도 매장들을 많이 가지고 있다

# %% [markdown]
# ## 매장의 위치를 지도에 표시

# %% [markdown]
# ### 지금까지 E/S와 인구수의 관계를 그래프 등으로 확인했다면 이제는 지도에서 직접확인해보자

# %%
sbed14 = sbed_o2
sbed14.head()
# Out:
#     City  Number_S  Number_E       E/S  Population
# 0  서울특별시     390.0     427.0  1.094872     9805506
# 1  부산광역시      89.0     144.0  1.617978     3440484
# 2  대구광역시      56.0      32.0  0.571429     2461002
# 3  광주광역시      40.0      25.0  0.625000     1501557
# 4  대전광역시      40.0      21.0  0.525000     1535445

# %%
import json
geo_path = 'skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %% [markdown]
# * 이디야의 매장 위치

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=7)

for n in ediya1.index:
    folium.Marker([ediya1['Latitude'][n], 
                   ediya1['Longtitude'][n]]).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# * 스타벅스의 매장 위치

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=7)

for n in starbucks1.index:
    folium.Marker([starbucks1['Latitude'][n], 
                   starbucks1['Longtitude'][n]]).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ⇒ 지도로 확인하기에도 스타벅스는 대도시 쪽으로 매장들이 몰려있고 이디야는 그 외의 도시에도 매장들이 분포되어있는 것을 확인 할 수 있다

# %% [markdown]
# ⇒ 지도를 확대한 후, 비교해서 매장의 위치를 보면 스타벅스의 매장과 이디야의 매장의 위치가 비슷함

# %% [markdown]
# ## ⇒결론

# %% [markdown]
# ### 이디야가 스타벅스 옆에 존재한다는 속설은 결국 절반만 맞는 말이라고 할 수 있다

# %% [markdown]
# * 지도에서 확인한 것처럼, 실제로 이디야는 스타벅스의 주변, 가격이 싼 상가에 입접을 하는 전략을 택하고 있다
# * 하지만 대전, 대구, 광주같은 도시들에서는 스타벅스의 60% 수준의 매장만을 가지고 있고
# * 인천에서는 약 3배의 매장 수를 가지고 있다
# * 또한, 중소도시에서도 스타벅스보다 많은 매장 수를 가지고 있다
# * 따라서, 이디야는 스타벅스 옆에 입점하는 전략과 스타벅스가 없어도 독자적으로 입점을 하는 전략을 다 사용하고 있다고 볼 수 있다
