# %% [markdown]
# # 소셜 네트워크 분석

# %% [markdown]
# ## 1. 비즈니스 이해
#
# ### Background: 어떠한 문제가 존재하는지 상황에 대해 알려진 기사, 논문, 보고서 등을 인용하여 현상을 구체적으로 기술하시기 바랍니다.
# - [[열려라 공부] 새 친구 '탐색 시기' 학교폭력도 늘어요](http://news.joins.com/article/21292322)
# - [학생 네트워크 중요해!](http://news.joins.com/article/21292322)
# - 새 학년이 시작되는 3월엔 새로 만난 학생 사이의 갈등도 생기기 마련이다. 송형호 서울 천호중 교사(전 서울시교육청학교폭력담당 파견교사)는 이를 두고 ‘3주의 징크스’라고 불렀다. 개학 직후 1~2주를 지나 3주차가 되면 크고 작은 학교폭력이 시작된다는 설명이다.
#
# ### Business Objectives: 기업(혹은 본인)에게 이 현상이 어떠한 이유로 분석을 해야 하는지 추상적(함축적)으로 기술하시기 바랍니다.
# - 교우관계 진단을 통해 “따돌림 위기군”을 사전에 파악하고, 학교 내 청소년 교우관계 문제를 해소하는데 도움이 되고자 함.
#
# ### Business Success Criteria: 비즈니스 관점에서 분석결과의 성공기준(정량적) 또는 유용한 결과에 대한 기준(정성적)을 설명하십시오.
# - 교사 입장에서 교우관계 진단을 통해, 집중적으로 관리해야할 학생군을 파악하고, 학기 초와 비교하여 학기 말에 1명(왕따) 혹은 2명의 학생 네트워크 수를 줄인다.
#
# ### Analysis Goals: 비즈니스 목표에 대한 의사결정 지원을 위해 실시하는 분석의 목표를 기술합니다.
# - 학생 네트워크 수의 변화 양상 분석, 소수 학생(1명 혹은 2명간) 네트워크 파악
# - ![외톨이 유형](외톨이.jpg)
# - 참조문헌(http://cyram.tistory.com/213)

# %% [markdown]
# ## 2. 데이터의 이해
# - 학기초 학생에 대한 설문조사를 실시하여 데이터를 수집함.
# - [구글 설문조사 활용](https://goo.gl/forms/QSPhpQmOpWwxT1gS2)
#     - 구글 설문: 학기 초 1회 실시(47명)
#     - 구글 설문: 학기 중간 1회 실시(47명)
# - 데이터 전처리 : 2개 entity를 결합 / 집계

# %% [markdown]
# ## 3. 데이터 준비

# %%
# 네트워크 분석을 지원하는 networkx, pydot 모듈을 설치해야 함.
# conda install -c anaconda networkx
# pip install pydot
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
# import pydot
# %matplotlib inline

# 폰트 문제 해결하기
import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# #### 네트워크 그래프 클래스
# - Graph: 이 클래스는 무방향 그래프를 구현합니다. 두 노드 사이의 여러 엣지를 무시합니다. 노드와 노드 사이에 자체 루프 에지를 허용합니다.
# - DiGraph: 방향성 그래프, 즉 방향성 엣지를 가진 그래프. 유향 그래프(Graph의 서브 클래스)에 공통의 조작을 제공합니다.
# - MultiGraph: 노드 쌍 사이에 여러 무방향 에지를 허용하는 유연한 그래프 클래스입니다. 추가 유연성은 일반적으로 중요하지 않지만 성능 저하를 가져옵니다.
# - MultiDiGraph: MultiGraph의 방향성 버전.

# %%
# 그래프 유형 선언
G1 = nx.Graph()
G2 = nx.DiGraph()
G3 = nx.MultiGraph()
G4 = nx.MultiDiGraph()

# %%
G = nx.Graph()
G.add_edge('A', 'B')
G.add_edge('B', 'D')
G.add_edge('A', 'C')
G.add_edge('C', 'D')
nx.shortest_path(G, 'A', 'D', weight='weight')

# %% [markdown]
# ### 데이터 임포트
# - 데이터 내 값: NaN은 하나의 열 단위로 존재하는데, 이는 해당 열의 인원이 출석하지 않음을 의미함. -> 제거
# - 데이터 내 값: - 은 본인이 본인을 평가할 수 없기 때문에 입력된 것
# - 데이터 내 값: 1 은 관계가 있음을 의미
# - 데이터 내 값: 0 은 관계가 없음을 의미

# %%
# 구글 설문 데이터를 불러옴.
data = pd.read_excel("studentnetwork_download.xlsx")
data.head()
# Out:
#      1. 경영학부 09학번 김진용  2. 경영학부 11학번 임철현  3. 경영학부 12학번 강예지  4. 경영학부 12학번 배성원  \
# 강승훈                 0                 0                 0                 0
# 황은택                 0                 0                 0                 0
# 허동숙                 0                 0                 0                 0
# 배성원                 0                 0                 0                 0
# 이종석                 0                 0                 0                 0
#
#      5. 경영학부 12학번 윤태성  6. 경영학부 12학번 최용환  7. 경영학부 12학번 김대엽  8. 경영학부 12학번 이호선  \
# 강승훈                 0                 0                 0                 0
# 황은택                 0                 0                 0                 0
# 허동숙                 0                 0                 0                 0
# 배성원                 1                 1                 0                 1
# 이종석                 0                 0                 0                 0
#
#      9. 경영학부 13학번 고성규  10. 경영학부 13학번 권오승         ...           \
# 강승훈                 0                  0         ...
# 황은택                 0                  0         ...
# 허동숙                 0                  0         ...
# 배성원                 0                  0         ...
# 이종석                 0                  1         ...
#
#      38. 경영학부 17학번 김엘레나  39. 경제학부 13학번 이충현  40. 경제학부 16학번 이예은  \
# 강승훈                   0                  0                  0
# 황은택                   0                  0                  0
# 허동숙                   0                  0                  0
# 배성원                   0                  0                  0
# 이종석                   0                  0                  0
#
#      41. 산업경영공학과 14학번 이주영  42. 영미언어문화학과 12학번 강승훈  43. 영미언어문화학과 12학번 허동숙  \
# 강승훈                     0                      0                      1
# 황은택                     0                      1                      1
# 허동숙                     0                      1                      0
# 배성원                     0                      0                      0
# 이종석                     0                      0                      0
#
#      44. 영미언어문화학과 14학번 추화정  45. 신문방송학과 13학번 장선호  46. 신문방송학과 14학번 김서현  \
# 강승훈                      0                    0                    0
# 황은택                      0                    0                    0
# 허동숙                      0                    0                    0
# 배성원                      0                    0                    0
# 이종석                      0                    0                    0
#
#      47. 정보사회학과 13학번 박상준
# 강승훈                    0
# 황은택                    0
# 허동숙                    0
# 배성원                    0
# 이종석                    0
#
# [5 rows x 47 columns]

# %%
# 설문에 참여를 참여를 안 한 열을 제거함.
# 생략
data = data.dropna(axis=1) # axis =1 열을 기준으로 삭제
data.head()
# Out:
#      1. 경영학부 09학번 김진용  2. 경영학부 11학번 임철현  3. 경영학부 12학번 강예지  4. 경영학부 12학번 배성원  \
# 강승훈                 0                 0                 0                 0
# 황은택                 0                 0                 0                 0
# 허동숙                 0                 0                 0                 0
# 배성원                 0                 0                 0                 0
# 이종석                 0                 0                 0                 0
#
#      5. 경영학부 12학번 윤태성  6. 경영학부 12학번 최용환  7. 경영학부 12학번 김대엽  8. 경영학부 12학번 이호선  \
# 강승훈                 0                 0                 0                 0
# 황은택                 0                 0                 0                 0
# 허동숙                 0                 0                 0                 0
# 배성원                 1                 1                 0                 1
# 이종석                 0                 0                 0                 0
#
#      9. 경영학부 13학번 고성규  10. 경영학부 13학번 권오승         ...           \
# 강승훈                 0                  0         ...
# 황은택                 0                  0         ...
# 허동숙                 0                  0         ...
# 배성원                 0                  0         ...
# 이종석                 0                  1         ...
#
#      38. 경영학부 17학번 김엘레나  39. 경제학부 13학번 이충현  40. 경제학부 16학번 이예은  \
# 강승훈                   0                  0                  0
# 황은택                   0                  0                  0
# 허동숙                   0                  0                  0
# 배성원                   0                  0                  0
# 이종석                   0                  0                  0
#
#      41. 산업경영공학과 14학번 이주영  42. 영미언어문화학과 12학번 강승훈  43. 영미언어문화학과 12학번 허동숙  \
# 강승훈                     0                      0                      1
# 황은택                     0                      1                      1
# 허동숙                     0                      1                      0
# 배성원                     0                      0                      0
# 이종석                     0                      0                      0
#
#      44. 영미언어문화학과 14학번 추화정  45. 신문방송학과 13학번 장선호  46. 신문방송학과 14학번 김서현  \
# 강승훈                      0                    0                    0
# 황은택                      0                    0                    0
# 허동숙                      0                    0                    0
# 배성원                      0                    0                    0
# 이종석                      0                    0                    0
#
#      47. 정보사회학과 13학번 박상준
# 강승훈                    0
# 황은택                    0
# 허동숙                    0
# 배성원                    0
# 이종석                    0
#
# [5 rows x 47 columns]

# %%
# 우리는 adjacency matrix나 edgelist가 필요함.
# 컬럼명을 변경해야함. ex) 1. 경영학부 10학번 이정우 -> 이정우
data.columns # 우선 컬럼명 조회
# Out:
# Index(['1. 경영학부 09학번 김진용', '2. 경영학부 11학번 임철현', '3. 경영학부 12학번 강예지',
#        '4. 경영학부 12학번 배성원', '5. 경영학부 12학번 윤태성', '6. 경영학부 12학번 최용환',
#        '7. 경영학부 12학번 김대엽', '8. 경영학부 12학번 이호선', '9. 경영학부 13학번 고성규',
#        '10. 경영학부 13학번 권오승', '11. 경영학부 13학번 민경민', '12. 경영학부 13학번 지수창',
#        '13. 경영학부 13학번 이찬희', '14. 경영학부 14학번 강슬기', '15. 경영학부 14학번 강연주',
#        '16. 경영학부 14학번 권혜민', '17. 경영학부 14학번 김재경', '18. 경영학부 14학번 우지원',
#        '19. 경영학부 14학번 유상연', '20. 경영학부 14학번 이종석', '21. 경영학부 14학번 전규리',
#        '22. 경영학부 14학번 조영욱', '23. 경영학부 14학번 황은택', '24. 경영학부 14학번 최유라',
#        '25. 경영학부 15학번 고민주', '26. 경영학부 15학번 정혜욱', '27. 경영학부 15학번 하수정',
#        '28. 경영학부 15학번 한명우', '29. 경영학부 15학번 나미영', '30. 경영학부 15학번 봉인성',
#        '31. 경영학부 15학번 이혜지', '32. 경영학부 15학번 채영석', '33. 경영학부 16학번 박민진',
#        '34. 경영학부 16학번 안예지', '35. 경영학부 17학번 박지성', '36. 경영학부 17학번 정재훈',
#        '37. 경영학부 17학번 한효경', '38. 경영학부 17학번 김엘레나', '39. 경제학부 13학번 이충현',
#        '40. 경제학부 16학번 이예은', '41. 산업경영공학과 14학번 이주영', '42. 영미언어문화학과 12학번 강승훈',
#        '43. 영미언어문화학과 12학번 허동숙', '44. 영미언어문화학과 14학번 추화정', '45. 신문방송학과 13학번 장선호',
#        '46. 신문방송학과 14학번 김서현', '47. 정보사회학과 13학번 박상준'],
#       dtype='object')

# %%
data.columns[0].split()
# Out:
# ['1.', '경영학부', '09학번', '김진용']

# %%
# 컬럼명 정리
column_list = []
for i in data.columns:
    column_list.append(i.split()[-1]) # 공백으로 나눠서 나오는 리스트의 맨 마지막 문자열[-1]이 바로 학생이름임.
column_list[:5]

# %%
data.columns = column_list
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-07275b8b862d> in <module>()
# ----> 1 data.columns = column_list
#       2 data.head()
#
# NameError: name 'column_list' is not defined

# %%
# 엣지리스트 만들기
edgelist = []
for i in data.index:
    for j in data.columns:
        if data.loc[i,j] == 1:
            edgelist.append((i,j))
        else:
            pass
edgelist
# Out:
# [('강승훈', '23. 경영학부 14학번 황은택'),
#  ('강승훈', '43. 영미언어문화학과 12학번 허동숙'),
#  ('황은택', '12. 경영학부 13학번 지수창'),
#  ('황은택', '19. 경영학부 14학번 유상연'),
#  ('황은택', '42. 영미언어문화학과 12학번 강승훈'),
#  ('황은택', '43. 영미언어문화학과 12학번 허동숙'),
#  ('허동숙', '23. 경영학부 14학번 황은택'),
#  ('허동숙', '42. 영미언어문화학과 12학번 강승훈'),
#  ('배성원', '5. 경영학부 12학번 윤태성'),
#  ('배성원', '6. 경영학부 12학번 최용환'),
#  ('배성원', '8. 경영학부 12학번 이호선'),
#  ('이종석', '10. 경영학부 13학번 권오승'),
#  ('이종석', '15. 경영학부 14학번 강연주'),
#  ('고민주', '28. 경영학부 15학번 한명우'),
#  ('고민주', '30. 경영학부 15학번 봉인성'),
#  ('고민주', '32. 경영학부 15학번 채영석'),
#  ('최용환', '4. 경영학부 12학번 배성원'),
#  ('최용환', '5. 경영학부 12학번 윤태성'),
#  ('최용환', '7. 경영학부 12학번 김대엽'),
#  ('최용환', '23. 경영학부 14학번 황은택'),
#  ('김재경', '14. 경영학부 14학번 강슬기'),
#  ('김재경', '18. 경영학부 14학번 우지원'),
#  ('김재경', '21. 경영학부 14학번 전규리'),
#  ('한효경', '10. 경영학부 13학번 권오승'),
#  ('한효경', '20. 경영학부 14학번 이종석'),
#  ('나미영', '1. 경영학부 09학번 김진용'),
#  ('나미영', '24. 경영학부 14학번 최유라'),
#  ('나미영', '30. 경영학부 15학번 봉인성'),
#  ('나미영', '31. 경영학부 15학번 이혜지'),
#  ('나미영', '38. 경영학부 17학번 김엘레나'),
#  ('나미영', '39. 경제학부 13학번 이충현'),
#  ('윤태성', '4. 경영학부 12학번 배성원'),
#  ('윤태성', '6. 경영학부 12학번 최용환'),
#  ('지수창', '2. 경영학부 11학번 임철현'),
#  ('지수창', '11. 경영학부 13학번 민경민'),
#  ('지수창', '13. 경영학부 13학번 이찬희'),
#  ('지수창', '15. 경영학부 14학번 강연주'),
#  ('지수창', '17. 경영학부 14학번 김재경'),
#  ('지수창', '19. 경영학부 14학번 유상연'),
#  ('지수창', '20. 경영학부 14학번 이종석'),
#  ('지수창', '23. 경영학부 14학번 황은택'),
#  ('지수창', '37. 경영학부 17학번 한효경'),
#  ('정재훈', '35. 경영학부 17학번 박지성'),
#  ('정재훈', '45. 신문방송학과 13학번 장선호'),
#  ('정재훈', '47. 정보사회학과 13학번 박상준'),
#  ('권오승', '2. 경영학부 11학번 임철현'),
#  ('권오승', '7. 경영학부 12학번 김대엽'),
#  ('권오승', '9. 경영학부 13학번 고성규'),
#  ('권오승', '20. 경영학부 14학번 이종석'),
#  ('권오승', '37. 경영학부 17학번 한효경'),
#  ('김진용', '29. 경영학부 15학번 나미영'),
#  ('김진용', '38. 경영학부 17학번 김엘레나'),
#  ('김진용', '39. 경제학부 13학번 이충현'),
#  ('최유라', '28. 경영학부 15학번 한명우'),
#  ('최유라', '29. 경영학부 15학번 나미영'),
#  ('최유라', '30. 경영학부 15학번 봉인성'),
#  ('최유라', '31. 경영학부 15학번 이혜지'),
#  ('최유라', '32. 경영학부 15학번 채영석'),
#  ('최유라', '46. 신문방송학과 14학번 김서현'),
#  ('이주영', '35. 경영학부 17학번 박지성'),
#  ('이주영', '44. 영미언어문화학과 14학번 추화정'),
#  ('이예은', '7. 경영학부 12학번 김대엽'),
#  ('이예은', '10. 경영학부 13학번 권오승'),
#  ('이예은', '15. 경영학부 14학번 강연주'),
#  ('이예은', '19. 경영학부 14학번 유상연'),
#  ('이예은', '21. 경영학부 14학번 전규리'),
#  ('추화정', '35. 경영학부 17학번 박지성'),
#  ('추화정', '41. 산업경영공학과 14학번 이주영'),
#  ('김대엽', '2. 경영학부 11학번 임철현'),
#  ('김대엽', '6. 경영학부 12학번 최용환'),
#  ('김대엽', '8. 경영학부 12학번 이호선'),
#  ('김대엽', '10. 경영학부 13학번 권오승'),
#  ('김대엽', '15. 경영학부 14학번 강연주'),
#  ('김대엽', '18. 경영학부 14학번 우지원'),
#  ('김대엽', '21. 경영학부 14학번 전규리'),
#  ('김대엽', '40. 경제학부 16학번 이예은'),
#  ('장선호', '36. 경영학부 17학번 정재훈'),
#  ('장선호', '46. 신문방송학과 14학번 김서현'),
#  ('장선호', '47. 정보사회학과 13학번 박상준'),
#  ('민경민', '2. 경영학부 11학번 임철현'),
#  ('민경민', '8. 경영학부 12학번 이호선'),
#  ('민경민', '9. 경영학부 13학번 고성규'),
#  ('민경민', '10. 경영학부 13학번 권오승'),
#  ('민경민', '12. 경영학부 13학번 지수창'),
#  ('민경민', '13. 경영학부 13학번 이찬희'),
#  ('민경민', '16. 경영학부 14학번 권혜민'),
#  ('민경민', '18. 경영학부 14학번 우지원'),
#  ('민경민', '23. 경영학부 14학번 황은택'),
#  ('민경민', '26. 경영학부 15학번 정혜욱'),
#  ('강연주', '2. 경영학부 11학번 임철현'),
#  ('강연주', '7. 경영학부 12학번 김대엽'),
#  ('강연주', '12. 경영학부 13학번 지수창'),
#  ('강연주', '14. 경영학부 14학번 강슬기'),
#  ('강연주', '16. 경영학부 14학번 권혜민'),
#  ('강연주', '18. 경영학부 14학번 우지원'),
#  ('강연주', '19. 경영학부 14학번 유상연'),
#  ('강연주', '20. 경영학부 14학번 이종석'),
#  ('강연주', '21. 경영학부 14학번 전규리'),
#  ('강연주', '23. 경영학부 14학번 황은택'),
#  ('강연주', '26. 경영학부 15학번 정혜욱'),
#  ('강연주', '40. 경제학부 16학번 이예은'),
#  ('박민진', '27. 경영학부 15학번 하수정'),
#  ('박민진', '34. 경영학부 16학번 안예지'),
#  ('임철현', '7. 경영학부 12학번 김대엽'),
#  ('임철현', '9. 경영학부 13학번 고성규'),
#  ('임철현', '10. 경영학부 13학번 권오승'),
#  ('임철현', '11. 경영학부 13학번 민경민'),
#  ('임철현', '12. 경영학부 13학번 지수창'),
#  ('임철현', '13. 경영학부 13학번 이찬희'),
#  ('임철현', '15. 경영학부 14학번 강연주'),
#  ('임철현', '18. 경영학부 14학번 우지원'),
#  ('임철현', '19. 경영학부 14학번 유상연'),
#  ('임철현', '26. 경영학부 15학번 정혜욱'),
#  ('김엘레나', '1. 경영학부 09학번 김진용'),
#  ('김엘레나', '29. 경영학부 15학번 나미영'),
#  ('김엘레나', '39. 경제학부 13학번 이충현'),
#  ('이혜지', '24. 경영학부 14학번 최유라'),
#  ('이혜지', '29. 경영학부 15학번 나미영'),
#  ('이혜지', '30. 경영학부 15학번 봉인성'),
#  ('이혜지', '32. 경영학부 15학번 채영석'),
#  ('이혜지', '46. 신문방송학과 14학번 김서현'),
#  ('강슬기', '15. 경영학부 14학번 강연주'),
#  ('강슬기', '17. 경영학부 14학번 김재경'),
#  ('강슬기', '18. 경영학부 14학번 우지원'),
#  ('강슬기', '21. 경영학부 14학번 전규리'),
#  ('전규리', '7. 경영학부 12학번 김대엽'),
#  ('전규리', '14. 경영학부 14학번 강슬기'),
#  ('전규리', '15. 경영학부 14학번 강연주'),
#  ('전규리', '16. 경영학부 14학번 권혜민'),
#  ('전규리', '17. 경영학부 14학번 김재경'),
#  ('전규리', '18. 경영학부 14학번 우지원'),
#  ('전규리', '40. 경제학부 16학번 이예은'),
#  ('고성규', '2. 경영학부 11학번 임철현'),
#  ('고성규', '10. 경영학부 13학번 권오승'),
#  ('고성규', '11. 경영학부 13학번 민경민'),
#  ('고성규', '12. 경영학부 13학번 지수창'),
#  ('고성규', '26. 경영학부 15학번 정혜욱'),
#  ('권혜민', '3. 경영학부 12학번 강예지'),
#  ('권혜민', '13. 경영학부 13학번 이찬희'),
#  ('권혜민', '15. 경영학부 14학번 강연주'),
#  ('권혜민', '18. 경영학부 14학번 우지원'),
#  ('권혜민', '19. 경영학부 14학번 유상연'),
#  ('권혜민', '21. 경영학부 14학번 전규리'),
#  ('권혜민', '23. 경영학부 14학번 황은택'),
#  ('권혜민', '28. 경영학부 15학번 한명우'),
#  ('채영석', '24. 경영학부 14학번 최유라'),
#  ('채영석', '25. 경영학부 15학번 고민주'),
#  ('채영석', '30. 경영학부 15학번 봉인성'),
#  ('채영석', '31. 경영학부 15학번 이혜지'),
#  ('정혜욱', '2. 경영학부 11학번 임철현'),
#  ('정혜욱', '9. 경영학부 13학번 고성규'),
#  ('정혜욱', '11. 경영학부 13학번 민경민'),
#  ('정혜욱', '47. 정보사회학과 13학번 박상준'),
#  ('유상연', '2. 경영학부 11학번 임철현'),
#  ('유상연', '3. 경영학부 12학번 강예지'),
#  ('유상연', '6. 경영학부 12학번 최용환'),
#  ('유상연', '13. 경영학부 13학번 이찬희'),
#  ('유상연', '15. 경영학부 14학번 강연주'),
#  ('유상연', '16. 경영학부 14학번 권혜민'),
#  ('유상연', '23. 경영학부 14학번 황은택'),
#  ('유상연', '28. 경영학부 15학번 한명우'),
#  ('유상연', '40. 경제학부 16학번 이예은'),
#  ('우지원', '2. 경영학부 11학번 임철현'),
#  ('우지원', '7. 경영학부 12학번 김대엽'),
#  ('우지원', '11. 경영학부 13학번 민경민'),
#  ('우지원', '14. 경영학부 14학번 강슬기'),
#  ('우지원', '15. 경영학부 14학번 강연주'),
#  ('우지원', '16. 경영학부 14학번 권혜민'),
#  ('우지원', '17. 경영학부 14학번 김재경'),
#  ('우지원', '21. 경영학부 14학번 전규리'),
#  ('우지원', '43. 영미언어문화학과 12학번 허동숙'),
#  ('조영욱', '8. 경영학부 12학번 이호선'),
#  ('박상준', '26. 경영학부 15학번 정혜욱'),
#  ('박상준', '36. 경영학부 17학번 정재훈'),
#  ('박상준', '45. 신문방송학과 13학번 장선호'),
#  ('이찬희', '2. 경영학부 11학번 임철현'),
#  ('이찬희', '11. 경영학부 13학번 민경민'),
#  ('이찬희', '12. 경영학부 13학번 지수창'),
#  ('이찬희', '16. 경영학부 14학번 권혜민'),
#  ('이찬희', '19. 경영학부 14학번 유상연'),
#  ('이찬희', '23. 경영학부 14학번 황은택'),
#  ('하수정', '33. 경영학부 16학번 박민진'),
#  ('하수정', '34. 경영학부 16학번 안예지'),
#  ('김서현', '24. 경영학부 14학번 최유라'),
#  ('김서현', '31. 경영학부 15학번 이혜지'),
#  ('김서현', '45. 신문방송학과 13학번 장선호'),
#  ('박지성', '36. 경영학부 17학번 정재훈'),
#  ('박지성', '41. 산업경영공학과 14학번 이주영'),
#  ('박지성', '44. 영미언어문화학과 14학번 추화정'),
#  ('안예지', '27. 경영학부 15학번 하수정'),
#  ('안예지', '33. 경영학부 16학번 박민진')]

# %%
len(edgelist) # 관계의 수를 확인
# Out:
# 191

# %%
# 방향성 그래프를 만들고, 우리가 만든 관계 리스트(edgelist)를 입력시킨다.
G = nx.DiGraph()
G.add_edges_from(edgelist)

# %%
# node 확인
G.node
# Out:
# NodeView(('강승훈', '23. 경영학부 14학번 황은택', '43. 영미언어문화학과 12학번 허동숙', '황은택', '12. 경영학부 13학번 지수창', '19. 경영학부 14학번 유상연', '42. 영미언어문화학과 12학번 강승훈', '허동숙', '배성원', '5. 경영학부 12학번 윤태성', '6. 경영학부 12학번 최용환', '8. 경영학부 12학번 이호선', '이종석', '10. 경영학부 13학번 권오승', '15. 경영학부 14학번 강연주', '고민주', '28. 경영학부 15학번 한명우', '30. 경영학부 15학번 봉인성', '32. 경영학부 15학번 채영석', '최용환', '4. 경영학부 12학번 배성원', '7. 경영학부 12학번 김대엽', '김재경', '14. 경영학부 14학번 강슬기', '18. 경영학부 14학번 우지원', '21. 경영학부 14학번 전규리', '한효경', '20. 경영학부 14학번 이종석', '나미영', '1. 경영학부 09학번 김진용', '24. 경영학부 14학번 최유라', '31. 경영학부 15학번 이혜지', '38. 경영학부 17학번 김엘레나', '39. 경제학부 13학번 이충현', '윤태성', '지수창', '2. 경영학부 11학번 임철현', '11. 경영학부 13학번 민경민', '13. 경영학부 13학번 이찬희', '17. 경영학부 14학번 김재경', '37. 경영학부 17학번 한효경', '정재훈', '35. 경영학부 17학번 박지성', '45. 신문방송학과 13학번 장선호', '47. 정보사회학과 13학번 박상준', '권오승', '9. 경영학부 13학번 고성규', '김진용', '29. 경영학부 15학번 나미영', '최유라', '46. 신문방송학과 14학번 김서현', '이주영', '44. 영미언어문화학과 14학번 추화정', '이예은', '추화정', '41. 산업경영공학과 14학번 이주영', '김대엽', '40. 경제학부 16학번 이예은', '장선호', '36. 경영학부 17학번 정재훈', '민경민', '16. 경영학부 14학번 권혜민', '26. 경영학부 15학번 정혜욱', '강연주', '박민진', '27. 경영학부 15학번 하수정', '34. 경영학부 16학번 안예지', '임철현', '김엘레나', '이혜지', '강슬기', '전규리', '고성규', '권혜민', '3. 경영학부 12학번 강예지', '채영석', '25. 경영학부 15학번 고민주', '정혜욱', '유상연', '우지원', '조영욱', '박상준', '이찬희', '하수정', '33. 경영학부 16학번 박민진', '김서현', '박지성', '안예지'))

# %%
# edge 확인
G.edges
# Out:
# OutEdgeView([('강승훈', '23. 경영학부 14학번 황은택'), ('강승훈', '43. 영미언어문화학과 12학번 허동숙'), ('황은택', '12. 경영학부 13학번 지수창'), ('황은택', '19. 경영학부 14학번 유상연'), ('황은택', '42. 영미언어문화학과 12학번 강승훈'), ('황은택', '43. 영미언어문화학과 12학번 허동숙'), ('허동숙', '23. 경영학부 14학번 황은택'), ('허동숙', '42. 영미언어문화학과 12학번 강승훈'), ('배성원', '5. 경영학부 12학번 윤태성'), ('배성원', '6. 경영학부 12학번 최용환'), ('배성원', '8. 경영학부 12학번 이호선'), ('이종석', '10. 경영학부 13학번 권오승'), ('이종석', '15. 경영학부 14학번 강연주'), ('고민주', '28. 경영학부 15학번 한명우'), ('고민주', '30. 경영학부 15학번 봉인성'), ('고민주', '32. 경영학부 15학번 채영석'), ('최용환', '4. 경영학부 12학번 배성원'), ('최용환', '5. 경영학부 12학번 윤태성'), ('최용환', '7. 경영학부 12학번 김대엽'), ('최용환', '23. 경영학부 14학번 황은택'), ('김재경', '14. 경영학부 14학번 강슬기'), ('김재경', '18. 경영학부 14학번 우지원'), ('김재경', '21. 경영학부 14학번 전규리'), ('한효경', '10. 경영학부 13학번 권오승'), ('한효경', '20. 경영학부 14학번 이종석'), ('나미영', '1. 경영학부 09학번 김진용'), ('나미영', '24. 경영학부 14학번 최유라'), ('나미영', '30. 경영학부 15학번 봉인성'), ('나미영', '31. 경영학부 15학번 이혜지'), ('나미영', '38. 경영학부 17학번 김엘레나'), ('나미영', '39. 경제학부 13학번 이충현'), ('윤태성', '4. 경영학부 12학번 배성원'), ('윤태성', '6. 경영학부 12학번 최용환'), ('지수창', '2. 경영학부 11학번 임철현'), ('지수창', '11. 경영학부 13학번 민경민'), ('지수창', '13. 경영학부 13학번 이찬희'), ('지수창', '15. 경영학부 14학번 강연주'), ('지수창', '17. 경영학부 14학번 김재경'), ('지수창', '19. 경영학부 14학번 유상연'), ('지수창', '20. 경영학부 14학번 이종석'), ('지수창', '23. 경영학부 14학번 황은택'), ('지수창', '37. 경영학부 17학번 한효경'), ('정재훈', '35. 경영학부 17학번 박지성'), ('정재훈', '45. 신문방송학과 13학번 장선호'), ('정재훈', '47. 정보사회학과 13학번 박상준'), ('권오승', '2. 경영학부 11학번 임철현'), ('권오승', '7. 경영학부 12학번 김대엽'), ('권오승', '9. 경영학부 13학번 고성규'), ('권오승', '20. 경영학부 14학번 이종석'), ('권오승', '37. 경영학부 17학번 한효경'), ('김진용', '29. 경영학부 15학번 나미영'), ('김진용', '38. 경영학부 17학번 김엘레나'), ('김진용', '39. 경제학부 13학번 이충현'), ('최유라', '28. 경영학부 15학번 한명우'), ('최유라', '29. 경영학부 15학번 나미영'), ('최유라', '30. 경영학부 15학번 봉인성'), ('최유라', '31. 경영학부 15학번 이혜지'), ('최유라', '32. 경영학부 15학번 채영석'), ('최유라', '46. 신문방송학과 14학번 김서현'), ('이주영', '35. 경영학부 17학번 박지성'), ('이주영', '44. 영미언어문화학과 14학번 추화정'), ('이예은', '7. 경영학부 12학번 김대엽'), ('이예은', '10. 경영학부 13학번 권오승'), ('이예은', '15. 경영학부 14학번 강연주'), ('이예은', '19. 경영학부 14학번 유상연'), ('이예은', '21. 경영학부 14학번 전규리'), ('추화정', '35. 경영학부 17학번 박지성'), ('추화정', '41. 산업경영공학과 14학번 이주영'), ('김대엽', '2. 경영학부 11학번 임철현'), ('김대엽', '6. 경영학부 12학번 최용환'), ('김대엽', '8. 경영학부 12학번 이호선'), ('김대엽', '10. 경영학부 13학번 권오승'), ('김대엽', '15. 경영학부 14학번 강연주'), ('김대엽', '18. 경영학부 14학번 우지원'), ('김대엽', '21. 경영학부 14학번 전규리'), ('김대엽', '40. 경제학부 16학번 이예은'), ('장선호', '36. 경영학부 17학번 정재훈'), ('장선호', '46. 신문방송학과 14학번 김서현'), ('장선호', '47. 정보사회학과 13학번 박상준'), ('민경민', '2. 경영학부 11학번 임철현'), ('민경민', '8. 경영학부 12학번 이호선'), ('민경민', '9. 경영학부 13학번 고성규'), ('민경민', '10. 경영학부 13학번 권오승'), ('민경민', '12. 경영학부 13학번 지수창'), ('민경민', '13. 경영학부 13학번 이찬희'), ('민경민', '16. 경영학부 14학번 권혜민'), ('민경민', '18. 경영학부 14학번 우지원'), ('민경민', '23. 경영학부 14학번 황은택'), ('민경민', '26. 경영학부 15학번 정혜욱'), ('강연주', '2. 경영학부 11학번 임철현'), ('강연주', '7. 경영학부 12학번 김대엽'), ('강연주', '12. 경영학부 13학번 지수창'), ('강연주', '14. 경영학부 14학번 강슬기'), ('강연주', '16. 경영학부 14학번 권혜민'), ('강연주', '18. 경영학부 14학번 우지원'), ('강연주', '19. 경영학부 14학번 유상연'), ('강연주', '20. 경영학부 14학번 이종석'), ('강연주', '21. 경영학부 14학번 전규리'), ('강연주', '23. 경영학부 14학번 황은택'), ('강연주', '26. 경영학부 15학번 정혜욱'), ('강연주', '40. 경제학부 16학번 이예은'), ('박민진', '27. 경영학부 15학번 하수정'), ('박민진', '34. 경영학부 16학번 안예지'), ('임철현', '7. 경영학부 12학번 김대엽'), ('임철현', '9. 경영학부 13학번 고성규'), ('임철현', '10. 경영학부 13학번 권오승'), ('임철현', '11. 경영학부 13학번 민경민'), ('임철현', '12. 경영학부 13학번 지수창'), ('임철현', '13. 경영학부 13학번 이찬희'), ('임철현', '15. 경영학부 14학번 강연주'), ('임철현', '18. 경영학부 14학번 우지원'), ('임철현', '19. 경영학부 14학번 유상연'), ('임철현', '26. 경영학부 15학번 정혜욱'), ('김엘레나', '1. 경영학부 09학번 김진용'), ('김엘레나', '29. 경영학부 15학번 나미영'), ('김엘레나', '39. 경제학부 13학번 이충현'), ('이혜지', '24. 경영학부 14학번 최유라'), ('이혜지', '29. 경영학부 15학번 나미영'), ('이혜지', '30. 경영학부 15학번 봉인성'), ('이혜지', '32. 경영학부 15학번 채영석'), ('이혜지', '46. 신문방송학과 14학번 김서현'), ('강슬기', '15. 경영학부 14학번 강연주'), ('강슬기', '17. 경영학부 14학번 김재경'), ('강슬기', '18. 경영학부 14학번 우지원'), ('강슬기', '21. 경영학부 14학번 전규리'), ('전규리', '7. 경영학부 12학번 김대엽'), ('전규리', '14. 경영학부 14학번 강슬기'), ('전규리', '15. 경영학부 14학번 강연주'), ('전규리', '16. 경영학부 14학번 권혜민'), ('전규리', '17. 경영학부 14학번 김재경'), ('전규리', '18. 경영학부 14학번 우지원'), ('전규리', '40. 경제학부 16학번 이예은'), ('고성규', '2. 경 ...

# %% [markdown]
# ### 그래프 그려보기
# ![색깔조합](named_colors.png)
# - [색상참조](https://matplotlib.org/2.0.2/examples/color/named_colors.html)
# - [파라미터 참조](https://networkx.github.io/documentation/latest/reference/generated/networkx.drawing.nx_pylab.draw_networkx.html#networkx.drawing.nx_pylab.draw_networkx)

# %% [markdown]
# - nx.draw(G) : 기본 그리기
# - nx.draw_circular(G) : 원 위에 노드 놓기
# - nx.draw_graphviz(G) : Graphviz 사용
# - nx.draw_kamada_kawai(G) : kamada_kawai 알고리즘
# - nx.draw_random(G) : 균등 분포를 이용한 랜덤
# - nx.draw_shell(G) : 동심원 위에 노드 놓기
# - nx.draw_spectral(G) : 그래프 라플라시안의 고유 벡터 기반
# - nx.draw_spring(G) : Fruchterman-Reingold force-directed alg. 기반

# %%
nx.draw_shell(G, node_size = [j * 10 for i, j in nx.degree(G)], # 노드 사이즈
                     node_color = "orange", # 노드 색상
                     edge_color = "slategray", # 엣지 색상
                     alpha = 0.7, # 노드와 엣지의 투명도
                     with_labels = True,# 노드 이름 표시 여부
                     font_size=10, # 폰트 사이즈
                     font_family='Malgun Gothic', # 한글설정
                     arrowsize = 10) # 화살표 크기
plt.rc('font', family='Malgun Gothic') # 폰트 문제
plt.title('한양대 2018 경데베 교우 네트워크') # 그래프 제목
plt.savefig('first_network.png') # 파일 저장

# %%
nx.draw_kamada_kawai(G, node_size = [j * 10 for i, j in nx.degree(G)], # 노드 사이즈
                     # node_color = "cadetblue", # 노드 색상
                     node_color = range(len(G.nodes)),
                     edge_color = "skyblue", # 엣지 색상
                     # edge_color=colors,
                     alpha = 0.7, # 노드와 엣지의 투명도
                     with_labels = True, # 노드 이름 표시 여부
                     font_size=10, # 폰트 사이즈
                     font_family='Malgun Gothic', # 한글설정
                     arrowsize = 10) # 화살표 크기
plt.rc('font', family='Malgun Gothic') # 폰트 문제
plt.title('한양대 2018 경데베 교우 네트워크') # 그래프 제목
plt.savefig('second_network.png') # 파일 저장

# %% [markdown]
# ## 4. 데이터 분석

# %% [markdown]
# ### 연결 정도(양적인 영향력)

# %%
nx.degree(G)
# Out:
# DiDegreeView({'강승훈': 2, '23. 경영학부 14학번 황은택': 9, '43. 영미언어문화학과 12학번 허동숙': 3, '황은택': 4, '12. 경영학부 13학번 지수창': 6, '19. 경영학부 14학번 유상연': 7, '42. 영미언어문화학과 12학번 강승훈': 2, '허동숙': 2, '배성원': 3, '5. 경영학부 12학번 윤태성': 2, '6. 경영학부 12학번 최용환': 4, '8. 경영학부 12학번 이호선': 4, '이종석': 2, '10. 경영학부 13학번 권오승': 7, '15. 경영학부 14학번 강연주': 10, '고민주': 3, '28. 경영학부 15학번 한명우': 4, '30. 경영학부 15학번 봉인성': 5, '32. 경영학부 15학번 채영석': 3, '최용환': 4, '4. 경영학부 12학번 배성원': 2, '7. 경영학부 12학번 김대엽': 7, '김재경': 3, '14. 경영학부 14학번 강슬기': 4, '18. 경영학부 14학번 우지원': 8, '21. 경영학부 14학번 전규리': 7, '한효경': 2, '20. 경영학부 14학번 이종석': 4, '나미영': 6, '1. 경영학부 09학번 김진용': 2, '24. 경영학부 14학번 최유라': 4, '31. 경영학부 15학번 이혜지': 4, '38. 경영학부 17학번 김엘레나': 2, '39. 경제학부 13학번 이충현': 3, '윤태성': 2, '지수창': 9, '2. 경영학부 11학번 임철현': 10, '11. 경영학부 13학번 민경민': 6, '13. 경영학부 13학번 이찬희': 5, '17. 경영학부 14학번 김재경': 4, '37. 경영학부 17학번 한효경': 2, '정재훈': 3, '35. 경영학부 17학번 박지성': 3, '45. 신문방송학과 13학번 장선호': 3, '47. 정보사회학과 13학번 박상준': 3, '권오승': 5, '9. 경영학부 13학번 고성규': 4, '김진용': 3, '29. 경영학부 15학번 나미영': 4, '최유라': 6, '46. 신문방송학과 14학번 김서현': 3, '이주영': 2, '44. 영미언어문화학과 14학번 추화정': 2, '이예은': 5, '추화정': 2, '41. 산업경영공학과 14학번 이주영': 2, '김대엽': 8, '40. 경제학부 16학번 이예은': 4, '장선호': 3, '36. 경영학부 17학번 정재훈': 3, '민경민': 10, '16. 경영학부 14학번 권혜민': 6, '26. 경영학부 15학번 정혜욱': 5, '강연주': 12, '박민진': 2, '27. 경영학부 15학번 하수정': 2, '34. 경영학부 16학번 안예지': 2, '임철현': 10, '김엘레나': 3, '이혜지': 5, '강슬기': 4, '전규리': 7, '고성규': 5, '권혜민': 8, '3. 경영학부 12학번 강예지': 2, '채영석': 4, '25. 경영학부 15학번 고민주': 1, '정혜욱': 4, '유상연': 9, '우지원': 9, '조영욱': 1, '박상준': 3, '이찬희': 6, '하수정': 2, '33. 경영학부 16학번 박민진': 2, '김서현': 3, '박지성': 3, '안예지': 2})

# %%
pd.DataFrame(list(nx.degree(G))).sort_values(by=1, ascending = False).head(10)
# Out:
#                     0   1
# 63                강연주  12
# 67                임철현  10
# 36   2. 경영학부 11학번 임철현  10
# 14  15. 경영학부 14학번 강연주  10
# 60                민경민  10
# 1   23. 경영학부 14학번 황은택   9
# 79                우지원   9
# 35                지수창   9
# 78                유상연   9
# 73                권혜민   8

# %% [markdown]
# ### 연결중심성
# - 연결 정도를 비율로 계산(상대적 비교)

# %%
nx.out_degree_centrality(G)

# %%
nx.in_degree_centrality(G)

# %%
nx.degree_centrality(G)

# %%
nx.closeness_centrality(G)

# %%
nx.betweenness_centrality(G)

# %% [markdown]
# ![삼각관계](triads.jpg)

# %% [markdown]
# - 1-003
# - 3-102
# - 4-021D
# - 6-021C

# %%
nx.triadic_census(G)
# Out:
# {'003': 94221,
#  '012': 14604,
#  '021C': 0,
#  '021D': 496,
#  '021U': 415,
#  '030C': 0,
#  '030T': 0,
#  '102': 0,
#  '111D': 0,
#  '111U': 0,
#  '120C': 0,
#  '120D': 0,
#  '120U': 0,
#  '201': 0,
#  '210': 0,
#  '300': 0}

# %% [markdown]
# ## 5. 분석 결과

# %%
print("Number of Nodes : ", nx.number_of_nodes(G))
print("Number of Edges : ", nx.number_of_edges(G))
degreelist = list(pd.DataFrame(list(nx.degree(G))).iloc[:,1])
print("Avg. Node Degree : ", float(sum(degreelist))/nx.number_of_nodes(G))
print("Avg. Path Length : ", nx.average_shortest_path_length(G))
# Out:
# Number of Nodes :  88
# Number of Edges :  191
# Avg. Node Degree :  4.340909090909091
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-22-83ac0a2ba5bb> in <module>()
#       3 degreelist = list(pd.DataFrame(list(nx.degree(G))).iloc[:,1])
#       4 print("Avg. Node Degree : ", float(sum(degreelist))/nx.number_of_nodes(G))
# ----> 5 print("Avg. Path Length : ", nx.average_shortest_path_length(G))
#
# ~\Miniconda3\lib\site-packages\networkx\algorithms\shortest_paths\generic.py in average_shortest_path_length(G, weight)
#     320     # Shortest path length is undefined if the graph is disconnected.
#     321     if G.is_directed() and not nx.is_weakly_connected(G):
# --> 322         raise nx.NetworkXError("Graph is not weakly connected.")
#     323     if not G.is_directed() and not nx.is_connected(G):
#     324         raise nx.NetworkXError("Graph is not connected.")
#
# NetworkXError: Graph is not weakly connected.

# %%
G.nodes
# Out:
# NodeView(('강승훈', '23. 경영학부 14학번 황은택', '43. 영미언어문화학과 12학번 허동숙', '황은택', '12. 경영학부 13학번 지수창', '19. 경영학부 14학번 유상연', '42. 영미언어문화학과 12학번 강승훈', '허동숙', '배성원', '5. 경영학부 12학번 윤태성', '6. 경영학부 12학번 최용환', '8. 경영학부 12학번 이호선', '이종석', '10. 경영학부 13학번 권오승', '15. 경영학부 14학번 강연주', '고민주', '28. 경영학부 15학번 한명우', '30. 경영학부 15학번 봉인성', '32. 경영학부 15학번 채영석', '최용환', '4. 경영학부 12학번 배성원', '7. 경영학부 12학번 김대엽', '김재경', '14. 경영학부 14학번 강슬기', '18. 경영학부 14학번 우지원', '21. 경영학부 14학번 전규리', '한효경', '20. 경영학부 14학번 이종석', '나미영', '1. 경영학부 09학번 김진용', '24. 경영학부 14학번 최유라', '31. 경영학부 15학번 이혜지', '38. 경영학부 17학번 김엘레나', '39. 경제학부 13학번 이충현', '윤태성', '지수창', '2. 경영학부 11학번 임철현', '11. 경영학부 13학번 민경민', '13. 경영학부 13학번 이찬희', '17. 경영학부 14학번 김재경', '37. 경영학부 17학번 한효경', '정재훈', '35. 경영학부 17학번 박지성', '45. 신문방송학과 13학번 장선호', '47. 정보사회학과 13학번 박상준', '권오승', '9. 경영학부 13학번 고성규', '김진용', '29. 경영학부 15학번 나미영', '최유라', '46. 신문방송학과 14학번 김서현', '이주영', '44. 영미언어문화학과 14학번 추화정', '이예은', '추화정', '41. 산업경영공학과 14학번 이주영', '김대엽', '40. 경제학부 16학번 이예은', '장선호', '36. 경영학부 17학번 정재훈', '민경민', '16. 경영학부 14학번 권혜민', '26. 경영학부 15학번 정혜욱', '강연주', '박민진', '27. 경영학부 15학번 하수정', '34. 경영학부 16학번 안예지', '임철현', '김엘레나', '이혜지', '강슬기', '전규리', '고성규', '권혜민', '3. 경영학부 12학번 강예지', '채영석', '25. 경영학부 15학번 고민주', '정혜욱', '유상연', '우지원', '조영욱', '박상준', '이찬희', '하수정', '33. 경영학부 16학번 박민진', '김서현', '박지성', '안예지'))

# %%
eG = nx.ego_graph(G, "조영욱", radius=1, center=True, undirected=False, distance=None)

# %%
nx.draw_kamada_kawai(eG, node_size = [j * 10 for i, j in nx.degree(G)], # 노드 사이즈
                     node_color = "cadetblue", # 노드 색상
                     edge_color = "skyblue", # 엣지 색상
                     alpha = 0.7, # 노드와 엣지의 투명도
                     with_labels = True, # 노드 이름 표시 여부
                     font_size=10, # 폰트 사이즈
                     font_family='Malgun Gothic', # 한글설정
                     arrowsize = 10) # 화살표 크기
plt.rc('font', family='Malgun Gothic') # 폰트 문제
plt.title('한양대 2018 경데베 교우 네트워크') # 그래프 제목
plt.savefig('third_network.png') # 파일 저장

# %% [markdown]
# ## 6. 시사점
